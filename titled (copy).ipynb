# %%
import random
import matplotlib.pyplot as plt
density=1000
incirke=0
outcirke=0
for dex in range(density):
    x=0
    y=0
    for dey in range(density):
        if((dex/density)**2+(dey/density)**2>1):
            outcirke+=1
        else:
            incirke+=1
            
print(incirke/outcirke)
# Out:
# 3.681341110601365

# %%
#mamo žogico z maso m 
# v zraku
#ob vsakem odboju izgubi nek procen energije
#začne na višini h 
# z hitrostn+jo vpfrint0
#in kotom phy
import matplotlib.pyplot as plt
import numpy as np





time=100

start=0
m=0.0027
airDensity=1.225
g= 9.81
bounce=0.5
h=0
r=0.02
crs=r*r*np.pi




v0=8

phy=-np.pi/4
dt=0.01
a=[0,0]
kup=0.1
v=[np.cos(phy)*v0,np.sin(phy)*v0,0]

x=[0]
y=[h]
z=[0]
#ax = plt.figure().add_subplot(projection='3d')
plantx=10
planty=10
plantm=1000
while(start<time):
    distx=plantx-x[len(x)-1]
    disty=planty-y[len(y)-1]
    
    distance=np.sqrt(disty**2+distx**2)
    sinfi=disty/distance
    cosfi=distx/distance
    fg=m*plantm/distance**2
    

    
    a=[cosfi*fg/m,sinfi*fg/m,0]
   # if(y[len(y)-1]<=0):

    #    kinx=(v[0]**2)*m/2
     #   kiny=(v[1]**2)*m/2
        #kinz=(v[2]**2)*m/2
       # v[0]=np.sqrt((kinx*bounce)*2/m)
       # v[1]=np.sqrt((kiny*bounce)*2/m)
       # v[2]=np.sqrt((kinz*bounce)*2/m)
    v=[v[0]+a[0]*dt,v[1]+a[1]*dt,v[2]+a[2]*dt]
    
    
    z.append(z[len(z)-1]+v[2]*dt)
   
    x.append(x[len(x)-1]+v[0]*dt)

    nexty=y[len(y)-1]+v[1]*dt
    #if(nexty>0):
    y.append(nexty)
    #else:
    #    y.append(0)
    start+=dt

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(x,y)
glx=10
gly=10
ax.scatter(glx,gly)
ax.set_aspect("equal", adjustable='box')

#ax.set_aspect('equal')

# %%
m=0
moč=0
albedo=0
radius=0
#funky kefeide sine wave numeric simulation in python prob lol

# %%
import numpy as np
import matplotlib.pyplot as plt
a=15000
b=10000
c=-25000
x=0.6
res=c/3*x**3+b/2*x**2+a*x
print(res)
v=np.sqrt(c/3*x**3+b/2*x**2+a*x*2/0.1)
print(v)


y=[]
maxlen=10;
tries=100;
dx=maxlen/tries
for nums in range(tries):
    x=nums*dx
    v=np.sqrt(c/3*x**3+b/2*x**2+a*x*2/0.1)
    y.append(v)

plt.plot(y)
# Out:
# 9000.0
# 424.26406871192853
# /tmp/ipykernel_4611/1118468517.py:19: RuntimeWarning: invalid value encountered in sqrt
#   v=np.sqrt(c/3*x**3+b/2*x**2+a*x*2/0.1)

# %%
import numpy as np
import matplotlib.pyplot as plt
m=100

# %%
import numpy as np
import matplotlib.pyplot as plt
massofsun=4e+30
censity=15000
gamma=5/3
